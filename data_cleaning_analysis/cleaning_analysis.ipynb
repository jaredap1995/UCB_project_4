# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# Read the data into a Pandas DataFrame
vehicles_df = pd.read_csv('Resources/vehicles.csv')
vehicles_df.tail()
# Out:
#                 id                                                url  \
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                      region_url  price    year manufacturer  \
# 426875  wyoming  https://wyoming.craigslist.org  23590  2019.0       nissan
# 426876  wyoming  https://wyoming.craigslist.org  30590  2020.0        volvo
# 426877  wyoming  https://wyoming.craigslist.org  34990  2020.0     cadillac
# 426878  wyoming  https://wyoming.craigslist.org  28990  2018.0        lexus
# 426879  wyoming  https://wyoming.craigslist.org  30590  2019.0          bmw
#
#                            model condition    cylinders  ... size       type  \
# 426875         maxima s sedan 4d      good  6 cylinders  ...  NaN      sedan
# 426876  s60 t5 momentum sedan 4d      good          NaN  ...  NaN      sedan
# 426877          xt4 sport suv 4d      good          NaN  ...  NaN  hatchback
# 426878           es 350 sedan 4d      good  6 cylinders  ...  NaN      sedan
# 426879  4 series 430i gran coupe      good          NaN  ...  NaN      coupe
#
#        paint_color                                          image_url  \
# 426875         NaN  https://images.craigslist.org/00o0o_iiraFnHg8q...
# 426876         red  https://images.craigslist.org/00x0x_15sbgnxCIS...
# 426877       white  https://images.craigslist.org/00L0L_farM7bxnxR...
# 426878      silver  https://images.craigslist.org/00z0z_bKnIVGLkDT...
# 426879         NaN  https://images.craigslist.org/00Y0Y_lEUocjyRxa...
#
#                                               description county state  \
# 426875  Carvana is the safer way to buy a car During t...    NaN    wy
# 426876  Carvana is the safer way to buy a car During t...    NaN    wy
# 426877  Carvana is the safer way to buy a car During t...    NaN    wy
# 426878  Carvana is the safer way to buy a car During t...    NaN    wy
# 426879  Carvana is the safer way to buy a car During t...    NaN    wy
#
#               lat       long              posting_date
# 426875  33.786500 -84.445400  2021-04-04T03:21:31-0600
# 426876  33.786500 -84.445400  2021-04-04T03:21:29-0600
# 426877  33.779214 -84.411811  2021-04-04T03:21:17-0600
# 426878  33.786500 -84.445400  2021-04-04T03:21:11-0600
# 426879  33.779214 -84.411811  2021-04-04T03:21:07-0600
#
# [5 rows x 26 columns]

# %%
# List column names
list(vehicles_df)
# Out:
# ['id',
#  'url',
#  'region',
#  'region_url',
#  'price',
#  'year',
#  'manufacturer',
#  'model',
#  'condition',
#  'cylinders',
#  'fuel',
#  'odometer',
#  'title_status',
#  'transmission',
#  'VIN',
#  'drive',
#  'size',
#  'type',
#  'paint_color',
#  'image_url',
#  'description',
#  'county',
#  'state',
#  'lat',
#  'long',
#  'posting_date']

# %%
# Get datatypes and null info
vehicles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
#  17  type          334022 non-null  object
#  18  paint_color   296677 non-null  object
#  19  image_url     426812 non-null  object
#  20  description   426810 non-null  object
#  21  county        0 non-null       float64
#  22  state         426880 non-null  object
#  23  lat           420331 non-null  float64
#  24  long          420331 non-null  float64
#  25  posting_date  426812 non-null  object
# dtypes: float64(5), int64(2), object(19)
# memory usage: 84.7+ MB

# %%
# Total number of unique car manufacturers 
manufacturers = len(vehicles_df["manufacturer"].unique())
manufacturers
# Out:
# 43

# %%
# Total number of unique car models
models = len(vehicles_df["model"].unique())
models
# Out:
# 29668

# %%
# Looking closer at model counts
model_counts = vehicles_df["model"].value_counts()
model_counts
# Out:
# f-150                 8009
# silverado 1500        5140
# 1500                  4211
# camry                 3135
# silverado             3023
#                       ...
# sequoia srs              1
# Citron 2CV               1
# s10 ls zr2               1
# 20                       1
# Dose Grand Caravan       1
# Name: model, Length: 29667, dtype: int64

# %%
# Count of listings
listing_count = len(vehicles_df.index)
listing_count
# Out:
# 426880

# %%
# Total number of unique years
years = len(vehicles_df["year"].unique())
years
# Out:
# 115

# %%
model_years = vehicles_df["year"].value_counts()
model_years.head()
# Out:
# 2017.0    36420
# 2018.0    36369
# 2015.0    31538
# 2013.0    30794
# 2016.0    30434
# Name: year, dtype: int64

# %%
# Drop irrelevant features
vehicles_df.drop(['id','url','region','region_url','model','fuel','drive','type','paint_color','county','VIN','lat','long','description','image_url'], axis=1, inplace=True)

# %%
# drop all null values by row
vehicles_df.dropna(axis=0, inplace=True)
vehicles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88268 entries, 31 to 426836
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         88268 non-null  int64
#  1   year          88268 non-null  float64
#  2   manufacturer  88268 non-null  object
#  3   condition     88268 non-null  object
#  4   cylinders     88268 non-null  object
#  5   odometer      88268 non-null  float64
#  6   title_status  88268 non-null  object
#  7   transmission  88268 non-null  object
#  8   size          88268 non-null  object
#  9   state         88268 non-null  object
#  10  posting_date  88268 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 8.1+ MB

# %%
# Change year to integer
vehicles_df['year'] = vehicles_df['year'].astype(int)

# %%
vehicles_df.sort_values(by='year', ascending=1).head(10)
# Out:
#         price  year manufacturer  condition    cylinders   odometer  \
# 42454   38250  1900        acura        new  4 cylinders     4500.0
# 289145   3990  1905    chevrolet  excellent  8 cylinders   202570.0
# 317864  27000  1913         ford   like new  4 cylinders  9999999.0
# 54732   85000  1913     cadillac       good  4 cylinders      150.0
# 350783  12000  1916        dodge       good  4 cylinders    30000.0
# 26712   16000  1918         ford       good  4 cylinders    56000.0
# 141891  13000  1922         ford  excellent  4 cylinders   999999.0
# 159206  18990  1923         ford   like new  8 cylinders     6652.0
# 294366  25000  1923         ford  excellent  8 cylinders     5600.0
# 189330  18500  1923         ford  excellent  8 cylinders     4963.0
#
#        title_status transmission         size state              posting_date
# 42454         clean    automatic     mid-size    ca  2021-04-30T16:19:15-0700
# 289145        clean    automatic    full-size    oh  2021-05-04T19:34:05-0400
# 317864        clean        other      compact    or  2021-04-22T09:50:49-0700
# 54732         clean       manual    full-size    ca  2021-05-03T16:45:21-0700
# 350783      missing       manual    full-size    sd  2021-04-08T08:32:19-0600
# 26712         clean    automatic    full-size    ca  2021-04-27T11:45:25-0700
# 141891        clean       manual     mid-size    il  2021-04-30T15:43:30-0500
# 159206        clean    automatic      compact    ia  2021-04-05T12:08:02-0500
# 294366        clean    automatic  sub-compact    oh  2021-04-11T17:32:46-0400
# 189330        clean    automatic      compact    ma  2021-04-22T14:29:47-0400

# %%
# Convert 'posting_date' to only the date
vehicles_df['posting_date'] = vehicles_df['posting_date'].str[:10]

vehicles_df['posting_date'] = pd.to_datetime(vehicles_df['posting_date'])

# %%
vehicles_df.head()
# Out:
#     price  year manufacturer  condition    cylinders  odometer title_status  \
# 31  15000  2013         ford  excellent  6 cylinders  128000.0        clean
# 55  19900  2004         ford       good  8 cylinders   88000.0        clean
# 59  14000  2012        honda  excellent  6 cylinders   95000.0        clean
# 65  22500  2001         ford       good  8 cylinders  144700.0        clean
# 73  15000  2017        dodge  excellent  8 cylinders   90000.0      rebuilt
#
#    transmission       size state posting_date
# 31    automatic  full-size    al   2021-05-03
# 55    automatic  full-size    al   2021-04-29
# 59    automatic  full-size    al   2021-04-27
# 65       manual  full-size    al   2021-04-26
# 73    automatic   mid-size    al   2021-04-24

# %%
# Manufacturers count
manufacturer_counts=vehicles_df.groupby('manufacturer').agg(
    num_listings=('manufacturer', 'size'),
    avg_price=('price','median'))

#sort by descending on manufacturer number of listings
manufacturer_counts=manufacturer_counts.sort_values(by='num_listings', ascending=False)
manufacturer_counts
# Out:
#                  num_listings  avg_price
# manufacturer
# ford                    17074    11500.0
# chevrolet               13538    10500.0
# toyota                   7783     8000.0
# honda                    5402     6800.0
# nissan                   4385     7500.0
# gmc                      3562    13999.0
# jeep                     3486    10500.0
# ram                      3269    19995.0
# dodge                    2869     6995.0
# bmw                      2444     9750.0
# mercedes-benz            2194     9500.0
# subaru                   2166     8200.0
# volkswagen               1943     7800.0
# hyundai                  1933     6995.0
# kia                      1553     7495.0
# chrysler                 1529     5990.0
# lexus                    1409     9995.0
# cadillac                 1405     9000.0
# buick                    1200     6900.0
# mazda                    1089     6500.0
# audi                     1013    10950.0
# acura                     799     6995.0
# pontiac                   789     4950.0
# lincoln                   771     7500.0
# infiniti                  734     8969.0
# volvo                     669     5900.0
# mitsubishi                666     7445.0
# mini                      476     7750.0
# mercury                   469     3995.0
# rover                     429    15000.0
# saturn                    372     3995.0
# porsche                   280    19000.0
# jaguar                    267     7800.0
# fiat                      137     7500.0
# harley-davidson            42    13740.0
# tesla                      38    42100.0
# alfa-romeo                 35    21900.0
# ferrari                    20    98900.0
# datsun                     16    15000.0
# land rover                  8     8247.5
# aston-martin                5    52000.0

# %%
# Chart showing listings count of manufacturers
plt.figure(figsize=(9,5))
plt.bar(manufacturer_counts.index, manufacturer_counts['num_listings'])
plt.title('Listings Count by Manufacturer')
plt.xlabel('Manufacturer')
plt.ylabel('Number of Listings')
plt.xticks(rotation=90)
plt.show()

# %%
# Average price and listings per state
state_counts=vehicles_df.groupby('state').agg(
num_listings=('state','size'),
avg_price=('price','median'))

state_counts.reset_index(inplace=True)
state_counts['state'] = state_counts['state'].str.upper()
state_counts
# Out:
#    state  num_listings  avg_price
# 0     AK           701    19995.0
# 1     AL           956    10500.0
# 2     AR           753     7500.0
# 3     AZ          1866    10000.0
# 4     CA          9640     9000.0
# 5     CO          1994     8995.0
# 6     CT          1095     6500.0
# 7     DC           535     7300.0
# 8     DE           257     7895.0
# 9     FL          7010     8675.0
# 10    GA          1127     6900.0
# 11    HI           519    15900.0
# 12    IA          1945     9995.0
# 13    ID          1620     9991.5
# 14    IL          1885     7975.0
# 15    IN          1368     7999.5
# 16    KS          1604     7995.0
# 17    KY          1084    12172.5
# 18    LA           528     6405.0
# 19    MA          1943     7995.0
# 20    MD           722     6500.0
# 21    ME           675    10495.0
# 22    MI          3123    10900.0
# 23    MN          2133    10800.0
# 24    MO           875    10900.0
# 25    MS           235     9500.0
# 26    MT           994    13960.5
# 27    NC          3266     9500.0
# 28    ND           228    16990.0
# 29    NE           293     9850.0
# 30    NH           601     8995.0
# 31    NJ          2120     7499.0
# 32    NM           928    10200.0
# 33    NV           601     8862.0
# 34    NY          4666     8995.0
# 35    OH          4366     6422.0
# 36    OK          1855     5850.0
# 37    OR          2489     8995.0
# 38    PA          3004     7990.0
# 39    RI           680     8250.0
# 40    SC          1401     8500.0
# 41    SD           358    12500.0
# 42    TN          1975    13800.0
# 43    TX          4517     8650.0
# 44    UT           242    14940.0
# 45    VA          2287     7950.0
# 46    VT          1024    14998.0
# 47    WA          1186     7200.0
# 48    WI          2682    11950.0
# 49    WV           155    10500.0
# 50    WY           157    15000.0

# %%
vehicles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88268 entries, 31 to 426836
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         88268 non-null  int64
#  1   year          88268 non-null  int64
#  2   manufacturer  88268 non-null  object
#  3   condition     88268 non-null  object
#  4   cylinders     88268 non-null  object
#  5   odometer      88268 non-null  float64
#  6   title_status  88268 non-null  object
#  7   transmission  88268 non-null  object
#  8   size          88268 non-null  object
#  9   state         88268 non-null  object
#  10  posting_date  88268 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(7)
# memory usage: 10.6+ MB

# %%
# Export cleaned csv file
vehicles_df.to_csv("Resources/vehicles_clean.csv", index=False)
